# %% [markdown]
# # Data science final project proposal
#
# **Name**: Jan Chudy<br>
# **School**: Milwaukee School of Engineering<br>
# **Course**: [CS 4981] CS Topics: Intro to Data Science<br>
# **Professor**: Jay Urbain, PhD<br>
# **Project's repository**: https://github.com/Emejzon/SteamGamesEDA
#
# ## Dataset
# I would like to work on a Steam Games dataset.
#
# **Name**: Steam Game Data<br>
# **Author**: <a href="https://data.world/craigkelly">Craig Kelly</a><br>
# **Data Source**: Combination of data from publicly available Steam API's and steamspy.com<br>
# **Links**:
# * Data set available on <a href="https://data.world/craigkelly/steam-game-data">data.world</a>
# * Full details on <a href="https://github.com/CraigKelly/steam-data">GitHub</a>

# %% [markdown]
# ### Dataset demonstration
# #### Sneak peak:
# Let's load the dataset into pandas and show first ten records.

# %%
import pandas as pd #import pandas

# %%
df=pd.read_csv("data/games-features.csv") # load the dataset
print(df.shape) # print out the shape of the dataset
df.head(10) # show first 10 records
# Out:
# (13357, 78)
#    QueryID  ResponseID                       QueryName  \
# 0       10          10                  Counter-Strike
# 1       20          20           Team Fortress Classic
# 2       30          30                   Day of Defeat
# 3       40          40              Deathmatch Classic
# 4       50          50       Half-Life: Opposing Force
# 5       60          60                        Ricochet
# 6       70          70                       Half-Life
# 7       80          80  Counter-Strike: Condition Zero
# 8       80          80  Counter-Strike: Condition Zero
# 9      130         130           Half-Life: Blue Shift
#
#                      ResponseName ReleaseDate  RequiredAge  DemoCount  \
# 0                  Counter-Strike  Nov 1 2000            0          0
# 1           Team Fortress Classic  Apr 1 1999            0          0
# 2                   Day of Defeat  May 1 2003            0          0
# ...

# %% [markdown]
# #### Features:
# * QueryID - (Integer) The original ID in idlist.csv
# * ResponseID - (Integer) The ID returned in the Steam response (should equal QueryID)
# * QueryName - (Text) The original name in idlist.csv
# * ResponseName - (Text) The name returned in the Steam response (should equal QueryName)
# * ReleaseDate - (Text) Appears to the be the initial release date for the game
# * RequiredAge - (Integer) list named required_age in JSON
# * DemoCount - (TextualCount) list named demos in JSON
# * DeveloperCount - (TextualCount) list named developers in JSON
# * DLCCount - (TextualCount) list named dlc in JSON
# * Metacritic - (Integer) numeric score from metacritic object in JSON
# * MovieCount - (TextualCount) list named movies in JSON (used object id for unique count)
# * PackageCount - (TextualCount) list named packages in JSON
# * RecommendationCount - (Integer) from recommendations.total in JSON
# * PublisherCount - (TextualCount) list named publishers in JSON
# * ScreenshotCount - (TextualCount) list named screenshots in JSON
# * AchievementCount - (Integer) achievements.total in JSON
# * AchievementHighlightedCount - (TextualCount) for achievements.highlighted in JSON
# * ControllerSupport - (Boolean) True if controller_support was full
# * IsFree - (Boolean) is_free in JSON
#
# ... See all features <a href="https://data.world/craigkelly/steam-game-data">HERE</a>

# %% [markdown]
# #### Quick observations:
# * There are some duplicit data
# * Some features have too much missing data to be used in analysis
# * It might be more interesting to analyze data samples separately (e.g. Game Genres...)

# %% [markdown]
# ## Objectives
# List of some objectives:
# * Do free games have more DLCs?
# * Examine increase of VR Support games according to time.
# * Examine game rating averages in time.
# * What attributes contribute to rating averages?
#
# **Note**: This is not a complete list of this project's objectives. I might have more ideas during the data exploration.
